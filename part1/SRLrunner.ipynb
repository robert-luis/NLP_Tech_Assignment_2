# %% [markdown]
# # SRL runner
#
# This script
#
# *Input:*
# - executionMode_dict
# - mode               -> ('production' / 'sample')
# - model              -> ('train' / 'test')
# - print_status       -> (True / False)
#
# *Output:*
# - executionMode_dict
# - tbc

# %% [markdown]
# ## Setup
#
# ### Imports
# #### General imports

# %% [markdown]
# #### Script imports

# %%
# %run 1_DataImport.ipynb
# %run 2_PredicatePrediction.ipynb
# %run 3_DataframeConversion.ipynb
# %run 4_FeatureExtraction.ipynb
# %run 5_ArgumentIdentification.ipynb
# %run 6_ArgumentClassification.ipynb

# %% [markdown]
# ## Variables Taken from Main
# -> will be handed over

# %%
# dictionary with meta information

'''

Dictionary to carry all the relevant information for 
    - input, 
    - intermediate, and 
    - output files including their paths
    
    
Possible execution modes:
    - 'production'
    - 'sample'
    - 'custom'
    
'''

executionMode_dict = {
    'production' : {
        'input' : {
            'train' : '../data/input/en_ewt-up-train.conllu',
            'test'  : '../data/input/en_ewt-up-test.conllu'
        },
        'intermediate': {
            
        },
        'output': {
            
        }
    },
    'sample' : {
        'input' : {
            'train' : '../data/input/srl_univprop_en.example.conll',
            'test'  : '../data/input/en_ewt-up-test.conllu'
        },
        'intermediate': {
            
        },
        'output': {
            
        }
    } 
}

# use these parameters for now
mode  = 'sample'
model = 'train'
print_status = True


#shows
executionMode_dict
# Out:
# {'production': {'input': {'train': '../data/input/en_ewt-up-train.conllu',
#    'test': '../data/input/en_ewt-up-test.conllu'},
#   'intermediate': {},
#   'output': {}},
#  'sample': {'input': {'train': '../data/input/srl_univprop_en.example.conll',
#    'test': '../data/input/en_ewt-up-test.conllu'},
#   'intermediate': {},
#   'output': {}}}

# %% [markdown]
# ## Pipeline

# %%
# wrap everything in the following function

#def runSRL(executionMode_dict):   
#    return executionMode_dict, output   # either model for trian or dataset for test

# %%
# 1. create dataframe
executionMode_dict = createDataFrame(executionMode_dict, 
                                     mode  = mode,
                                     model = model,
                                     print_status = print_status)

# 2. predict predicates
executionMode_dict = predictPredicates(executionMode_dict, 
                                       mode  = mode,
                                       model = model,
                                       print_status = print_status)

# 3. convert/ expand dataframe
executionMode_dict = convertDataframe(executionMode_dict, 
                                      mode  = mode,
                                      model = model,
                                      print_status = print_status)

# 4. extract features
executionMode_dict = extractFeatures(executionMode_dict, 
                                      mode  = mode,
                                      model = model,
                                      print_status = print_status)

# 5. identify arguments
executionMode_dict = identifyArguments(executionMode_dict, 
                                      mode  = mode,
                                      model = model,
                                      print_status = print_status)

# 6. predict arguments
executionMode_dict, output = classifyArguments(executionMode_dict, 
                                       mode  = mode,
                                       model = model,
                                       print_status = print_status)
# Out:
# #### 1 Data Import ####
#
#
#  - # Sentences in file: 5
#  - # Tokens in file: 59
#  - Maxium of columns in file: 14
#
#   - ## 6 sentences were added to dataframe.
#  - Dataframe saved under: ../data/intermediate/sample_train_01_importedData.csv
#    sentenceId  id     form    lemma   upos xpos  \
# 0           0   1   Really   really    ADV   RB
# 1           0   2  enjoyed    enjoy   VERB  VBD
# 2           0   3       it       it   PRON  PRP
# 3           0   4        .        .  PUNCT    .
# 4           1   1  Compare  compare   VERB  VBN
#
#                                                morph  head     dep  head_dep  \
# 0                                                  _     2  advmod  2:advmod
# 1                   Mood=Ind|Tense=Past|VerbForm=Fin     0    root    0:root
# 2  Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...     2     obj     2:obj
# 3                                                  _     2   punct   2:punct
# 4                           Tense=Past|VerbForm=Part     8   advcl   8:advcl
#
#            space   predicate     label label1    label2  predicate_prediction
# 0              _           _  ARGM-EXT      _         _                 False
# 1              _    enjoy.01         V      _         _                 False
# 2  SpaceAfter=No           _      ARG1      _         _                 False
# 3              _           _         _      _         _                 False
# 4              _  compare.01         V      _  ARGM-ADV                 False
# #### 2 Predicate Prediction ####
#
#
#  - completed
#
#
# #### 3 Data Conversion ####
#
#
#  - # of lines in dataframe before conversion: 59
#  - # of lines in dataframe after conversion: 166
#    sentenceId  sentenceRepetition  id     form    lemma   upos xpos  \
# 0           0                   0   1   Really   really    ADV   RB
# 1           0                   0   2  enjoyed    enjoy   VERB  VBD
# 2           0                   0   3       it       it   PRON  PRP
# 3           0                   0   4        .        .  PUNCT    .
# 4           1                   0   1  Compare  compare   VERB  VBN
#
#                                                morph  head     dep  head_dep  \
# 0                                                  _     2  advmod  2:advmod
# 1                   Mood=Ind|Tense=Past|VerbForm=Fin     0    root    0:root
# 2  Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...     2     obj     2:obj
# 3                                                  _     2   punct   2:punct
# 4                           Tense=Past|VerbForm=Part     8   advcl   8:advcl
#
#            space  predicate_prediction  label_ident_prediction  \
# 0              _                 False                     NaN
# 1              _                 False                     NaN
# 2  SpaceAfter=No                 False                     NaN
# 3              _                 False                     NaN
# 4              _                 False                     NaN
#
#    label_prediction  predicate_gold  label_ident_gold  label_gold
# 0               NaN           False              True         NaN
# 1               NaN            True              True         NaN
# 2               NaN           False              True         NaN
# 3               NaN           False              True         NaN
# 4               NaN            True              True         NaN
# #### 4 Feature Extraction ####
#
#
#  Features extracted:
#  - Constituents
#  - Passive / Active
#  - ...
#
#  - completed
#    sentenceId  sentenceRepetition  id     form    lemma   upos xpos  \
# 0           0                   0   1   Really   really    ADV   RB
# 1           0                   0   2  enjoyed    enjoy   VERB  VBD
# 2           0                   0   3       it       it   PRON  PRP
# 3           0                   0   4        .        .  PUNCT    .
# 4           1                   0   1  Compare  compare   VERB  VBN
#
#                                                morph  head     dep  head_dep  \
# 0                                                  _     2  advmod  2:advmod
# 1                   Mood=Ind|Tense=Past|VerbForm=Fin     0    root    0:root
# 2  Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...     2     obj     2:obj
# 3                                                  _     2   punct   2:punct
# 4                           Tense=Past|VerbForm=Part     8   advcl   8:advcl
#
#            space  predicate_prediction  label_ident_prediction  \
# 0              _                 False                     NaN
# 1              _                 False                     NaN
# 2  SpaceAfter=No                 False                     NaN
# 3              _                 False                     NaN
# 4              _                 False                     NaN
#
#    label_prediction  predicate_gold  label_ident_gold  label_gold
# 0               NaN           False              True         NaN
# 1               NaN            True              True         NaN
# 2               NaN           False              True         NaN
# 3               NaN           False              True         NaN
# 4               NaN            True              True         NaN
# #### 5 Argument Identification ####
#
#
#  - completed
#    sentenceId  sentenceRepetition  id     form    lemma   upos xpos  \
# 0           0                   0   1   Really   really    ADV   RB
# 1           0                   0   2  enjoyed    enjoy   VERB  VBD
# 2           0                   0   3       it       it   PRON  PRP
# 3           0                   0   4        .        .  PUNCT    .
# 4           1                   0   1  Compare  compare   VERB  VBN
#
#                                                morph  head     dep  head_dep  \
# 0                                                  _     2  advmod  2:advmod
# 1                   Mood=Ind|Tense=Past|VerbForm=Fin     0    root    0:root
# 2  Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...     2     obj     2:obj
# 3                                                  _     2   punct   2:punct
# 4                           Tense=Past|VerbForm=Part     8   advcl   8:advcl
#
#            space  predicate_prediction  label_ident_prediction  \
# 0              _                 False                     NaN
# 1              _                 False                     NaN
# 2  SpaceAfter=No                 False                     NaN
# 3              _                 False                     NaN
# 4              _                 False                     NaN
#
#    label_prediction  predicate_gold  label_ident_gold  label_gold
# 0               NaN           False              True         NaN
# 1               NaN            True              True         NaN
# 2               NaN           False              True         NaN
# 3               NaN           False              True         NaN
# 4               NaN            True              True         NaN
# #### 2 Predicate Prediction ####
#
#
#  - completed
