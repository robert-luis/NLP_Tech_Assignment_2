# %% [markdown]
# # 5 Argument Identification
#
# This script provides a function to identify arguments per predicate <br>
#
#
# *Input:*
# - executionMode_dict
# - mode               -> ('production' / 'sample')
# - model              -> ('train' / 'test')
# - print_status       -> (True / False)
# - sentence_limit = None  (limit of sentences to import (default: None)
#
# *Output:*
# - executionMode_dict

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import numpy  as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading data in

# %%
def identifyArguments(executionMode_dict,
                      mode,                   #('production' / 'sample')
                      model,                  #('train' / 'test')
                      print_status   = False,
                      sentence_limit = None):
    

    path_to_input = executionMode_dict[mode]['intermediate'][model]['04_FeaturesExtracted']
    path_to_save = '../data/intermediate/' + mode + '_' + model +'_05_identifiedArguments.csv'
    executionMode_dict[mode]['intermediate'][model]['05_identifiedArguments'] = path_to_save
    
    # read dataframe in
    df = pd.read_csv(path_to_input)
    
    # insert predicted predicates here
    df['predicate_prediction'] = False

    display(df.head(5))
    ## insert here
    
    
    ## variable
    #reference column for predicates :  prediction vs truth
    predicate_column = 'predicate_prediction'
    #predicate_column = 'predicate_gold'



    # assign only subset of dataframe with 
    # uncomment if you want to restrict for this or another sentence
    df = df[df.sentenceId == 1].copy()


    # loop through sentences
    for s_id in df.sentenceId.unique():

        # filter for only this sentence
        df_sentence = df[df.sentenceId == s_id]

        # initiate np array to insert preditioncs
        predicates = np.full(len(df_sentence.id.unique()), False)

        ### find all predicates of that sentence 

        # loop through each repetition
        for s_rep in df_sentence.sentenceRepetition.unique():

            # create new subframe for working within this repetition of sentence
            df_sentence_repetition = df_sentence[df_sentence.sentenceRepetition == s_rep]


            ###  identify arguments (their indices)

            ## 1. identify id of predicate
            predicate_id = int(df_sentence_repetition[df_sentence_repetition[predicate_column] == True].id)

            predicate_identification = np.where(df_sentence_repetition[predicate_column] == True)[0]
            if len(predicate_identification) == 1:
                index_of_pred = np.where(df_sentence_repetition[predicate_column] == True)[0][0]
            index_of_pred

            predicates[index_of_pred] = True


        # loop through each repetition
        for s_rep in df_sentence.sentenceRepetition.unique():

            # create new subframe for working within this repetition of sentence
            df_sentence_repetition = df_sentence[df_sentence.sentenceRepetition == s_rep]

            # initiate np array to insert preditioncs
            # pred = np.full(len(df_sentence_repetition), False)


            ###  identify arguments (their indices)

            ## 1. identify id of predicate
            predicate_id = int(df_sentence_repetition[df_sentence_repetition[predicate_column] == True].id)

            ## RULE 1
            # ->take subset which have predicate id as head
            #df_potentials = df_sentence_repetition[df_sentence_repetition['head'] == predicate_id]
            pred = np.array(df_sentence_repetition['head'] == predicate_id)

            # set label_intent prediction to true
            #df_potentials.label_ident_prediction = True
            #display(df_potentials)


            ## RULE 2
            # -> exclude punctuation
            punct_index = df_sentence_repetition[df_sentence_repetition.dep == 'punct'].id - 1
            pred[punct_index] = False

            ## RULE 3
            # -> exclude all the identified predicates from arguments
            for i in range(len(pred)):
                # if this token is a predicate
                if predicates[i] == True:
                    pred[i] = False


            # assign value to all features
            df_sentence_repetition.label_ident_prediction = pred
    
    
    
    
    #write dataframe out
    df.to_csv(path_to_save, index=False)
    
    
    if print_status == True:
        
        print('\n\n#### 5 Argument Identification ####\n\n')
        print(' - completed')
    
    return executionMode_dict

# %%
#path_to_input = executionMode_dict[mode]['intermediate'][model]['04_FeaturesExtracted']
path_to_input = '../data/intermediate/' + 'sample' + '_' + 'train' + '_04_ExtractedFeatures.csv'
#executionMode_dict[mode]['intermediate'][model]['05_identifiedArguments'] = path_to_save

# read dataframe in
df = pd.read_csv(path_to_input)

# insert predicted predicates here
df['predicate_prediction'] = False

display(df.head(15))
## insert here
# Out:
#     sentenceId  sentenceRepetition  id        form       lemma   upos xpos  \
# 0            0                   0   1      Really      really    ADV   RB
# 1            0                   0   2     enjoyed       enjoy   VERB  VBD
# 2            0                   0   3          it          it   PRON  PRP
# 3            0                   0   4           .           .  PUNCT    .
# 4            1                   0   1     Compare     compare   VERB  VBN
# 5            1                   0   2          to          to    ADP   IN
# 6            1                   0   3        last        last    ADJ   JJ
# 7            1                   0   4      decade      decade   NOUN   NN
# 8            1                   0   5        this        this    DET   DT
# 9            1                   0   6  University  University  PROPN  NNP
# 10           1                   0   7          is          be    AUX  VBZ
# 11           1                   0   8     gaining        gain   VERB  VBG
# 12           1                   0   9        more        more    ADJ  JJR
# 13           1                   0  10    prestige    prestige   NOUN   NN
# 14           1                   0  11          in          in    ADP   IN
#
#                                                 morph  head     dep  head_dep  \
# 0                                                   _     2  advmod  2:advmod
# 1                    Mood=Ind|Tense=Past|VerbForm=Fin     0    root    0:root
# 2   Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...     2     obj     2:obj
# 3                                                   _     2   punct   2:punct
# 4                            Tense=Past|VerbForm=Part     8   advcl   8:advcl
# 5                                                   _     4    case    4:case
# 6                                          Degree=Pos     4    amod    4:amod
# 7                                         Number=Sing     1     obl  1:obl:to
# 8                            Number=Sing|PronType=Dem     6     det     6:det
# 9                                         Number=Sing     8   nsubj   8:nsubj
# 10  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...     8     aux     8:aux
# 11                                       VerbForm=Ger     0    root    0:root
# 12                                         Degree=Cmp    10    amod   10:amod
# 13                                        Number=Sing     8     obj     8:obj
# 14                                                  _    13    case   13:case
#
#             space  predicate_prediction  label_ident_prediction  \
# 0               _                 False                     NaN
# 1               _                 False                     NaN
# 2   SpaceAfter=No                 False                     NaN
# 3               _                 False                     NaN
# 4               _                 False                     NaN
# 5               _                 False                     NaN
# 6               _                 False                     NaN
# 7               _                 False                     NaN
# 8               _                 False                     NaN
# 9               _                 False                     NaN
# 10              _                 False                     NaN
# 11              _                 False                     NaN
# 12              _                 False                     NaN
# 13              _                 False                     NaN
# 14              _                 False                     NaN
#
#     label_prediction  predicate_gold  label_ident_gold label_gold  passive  \
# 0                NaN           False              True   ARGM-EXT      NaN
# 1                NaN            True             False          _      NaN
# 2                NaN           False              True       ARG1      NaN
# 3                NaN           False             False          _      NaN
# 4                NaN            True             False          _      NaN
# 5                NaN           False             False          _      NaN
# 6                NaN           False             False          _      NaN
# 7                NaN           False              True       ARG2      NaN
# 8                NaN           False             False          _      NaN
# 9                NaN           False             False          _      NaN
# 10               NaN           False             False          _      NaN
# 11               NaN           False             False          _      NaN
# 12               NaN           False             False          _      NaN
# 13               NaN           False             False          _      NaN
# 14               NaN           False             False          _      NaN
#
#                                      full_constituent
# 0                                              Really
# 1                                  Really enjoyed it.
# 2                                                  it
# 3                                                   .
# 4   Compare to last decade this University is gain...
# 5                                      to last decade
# 6                                                last
# 7                                         last decade
# 8                                                this
# 9                                     this University
# 10                                                 is
# 11  to last decade this University is gaining more...
# 12                                               more
# 13                                      more prestige
# 14                             in International level

# %%
## variable
#reference column for predicates :  prediction vs truth
predicate_column = 'predicate_prediction'
predicate_column = 'predicate_gold'



# assign only subset of dataframe with 
# uncomment if you want to restrict for this or another sentence
df = df[df.sentenceId == 1].copy()


# loop through sentences
for s_id in df.sentenceId.unique():
    
    # filter for only this sentence
    df_sentence = df[df.sentenceId == s_id]
    
    # initiate np array to insert preditioncs
    predicates = np.full(len(df_sentence.id.unique()), False)
    
    ### find all predicates of that sentence 
    
    # loop through each repetition
    for s_rep in df_sentence.sentenceRepetition.unique():
        
        # create new subframe for working within this repetition of sentence
        df_sentence_repetition = df_sentence[df_sentence.sentenceRepetition == s_rep]
        
        
        ###  identify arguments (their indices)
        
        ## 1. identify id of predicate
        predicate_id = int(df_sentence_repetition[df_sentence_repetition[predicate_column] == True].id)
    
        predicate_identification = np.where(df_sentence_repetition[predicate_column] == True)[0]
        if len(predicate_identification) == 1:
            index_of_pred = np.where(df_sentence_repetition[predicate_column] == True)[0][0]
        index_of_pred
        
        predicates[index_of_pred] = True

    
    # loop through each repetition
    for s_rep in df_sentence.sentenceRepetition.unique():
        
        # create new subframe for working within this repetition of sentence
        df_sentence_repetition = df_sentence[df_sentence.sentenceRepetition == s_rep]
        
        # initiate np array to insert preditioncs
        # pred = np.full(len(df_sentence_repetition), False)
        
        
        ###  identify arguments (their indices)
        
        ## 1. identify id of predicate
        predicate_id = int(df_sentence_repetition[df_sentence_repetition[predicate_column] == True].id)
        
        ## RULE 1
        # ->take subset which have predicate id as head
        #df_potentials = df_sentence_repetition[df_sentence_repetition['head'] == predicate_id]
        pred = np.array(df_sentence_repetition['head'] == predicate_id)
        
        # set label_intent prediction to true
        #df_potentials.label_ident_prediction = True
        #display(df_potentials)
        
        
        ## RULE 2
        # -> exclude punctuation
        punct_index = df_sentence_repetition[df_sentence_repetition.dep == 'punct'].id - 1
        pred[punct_index] = False
        
        ## RULE 3
        # -> exclude all the identified predicates from arguments
        for i in range(len(pred)):
            # if this token is a predicate
            if predicates[i] == True:
                pred[i] = False

        
        # assign value to all features
        df_sentence_repetition.label_ident_prediction = pred
        
        
        
        
        
        print  ('\n** sentence : ', s_id, 
                '\n*  sentence repetition :', s_rep)
        display( df_sentence_repetition, '\n')
        
    break
# Out:
# ** sentence :  1
# *  sentence repetition : 0
#     sentenceId  sentenceRepetition  id           form          lemma   upos  \
# 4            1                   0   1        Compare        compare   VERB
# 5            1                   0   2             to             to    ADP
# 6            1                   0   3           last           last    ADJ
# 7            1                   0   4         decade         decade   NOUN
# 8            1                   0   5           this           this    DET
# 9            1                   0   6     University     University  PROPN
# 10           1                   0   7             is             be    AUX
# 11           1                   0   8        gaining           gain   VERB
# 12           1                   0   9           more           more    ADJ
# 13           1                   0  10       prestige       prestige   NOUN
# 14           1                   0  11             in             in    ADP
# 15           1                   0  12  International  international    ADJ
# 16           1                   0  13          level          level   NOUN
#
#    xpos                                              morph  head    dep  \
# 4   VBN                           Tense=Past|VerbForm=Part     8  advcl
# 5    IN                                                  _     4   case
# 6    JJ                                         Degree=Pos     4   amod
# 7    NN                                        Number=Sing     1    obl
# 8    DT                           Number=Sing|PronType=Dem     6    det
# 9   NNP                                        Number=Sing     8  nsubj
# 10  VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...     8    aux
# 11  VBG                                       VerbForm=Ger     0   root
# 12  JJR                                         Degree=Cmp    10   amod
# 13   NN                                        Number=Sing     8    obj
# 14   IN                                                  _    13   case
# 15   JJ                                         Degree=Pos    13   amod
# 16   NN                                        Number=Sing     8    obl
#
#     head_dep space  predicate_prediction  label_ident_prediction  \
# 4    8:advcl     _                 False                   False
# 5     4:case     _                 False                   False
# 6     4:amod     _                 False                   False
# 7   1:obl:to     _                 False                    True
# 8      6:det     _                 False                   False
# 9    8:nsubj     _                 False                   False
# 10     8:aux     _                 False                   False
# 11    0:root     _                 False                   False
# 12   10:amod     _                 False                   False
# 13     8:obj     _                 False                   False
# 14   13:case     _                 False                   False
# 15   13:amod     _                 False                   False
# 16  8:obl:in     _                 False                   False
#
#     label_prediction  predicate_gold  label_ident_gold label_gold  passive  \
# 4                NaN            True             False          _      NaN
# 5                NaN           False             False          _      NaN
# 6                NaN           False             False          _      NaN
# 7                NaN           False              True       ARG2      NaN
# 8                NaN           False             False          _      NaN
# 9                NaN           False             False          _      NaN
# 10               NaN           False             False          _      NaN
# 11               NaN           False             False          _      NaN
# 12               NaN           False             False          _      NaN
# 13               NaN           False             False          _      NaN
# 14               NaN           False             False          _      NaN
# 15               NaN           False             False          _      NaN
# 16               NaN           False             False          _      NaN
#
#                                      full_constituent
# 4   Compare to last decade this University is gain...
# 5                                      to last decade
# 6                                                last
# 7                                         last decade
# 8                                                this
# 9                                     this University
# 10                                                 is
# 11  to last decade this University is gaining more...
# 12                                               more
# 13                                      more prestige
# 14                             in International level
# 15                                      International
# 16                                International level
# '\n'
# ** sentence :  1
# *  sentence repetition : 1
#     sentenceId  sentenceRepetition  id           form          lemma   upos  \
# 17           1                   1   1        Compare        compare   VERB
# 18           1                   1   2             to             to    ADP
# 19           1                   1   3           last           last    ADJ
# 20           1                   1   4         decade         decade   NOUN
# 21           1                   1   5           this           this    DET
# 22           1                   1   6     University     University  PROPN
# 23           1                   1   7             is             be    AUX
# 24           1                   1   8        gaining           gain   VERB
# 25           1                   1   9           more           more    ADJ
# 26           1                   1  10       prestige       prestige   NOUN
# 27           1                   1  11             in             in    ADP
# 28           1                   1  12  International  international    ADJ
# 29           1                   1  13          level          level   NOUN
#
#    xpos                                              morph  head    dep  \
# 17  VBN                           Tense=Past|VerbForm=Part     8  advcl
# 18   IN                                                  _     4   case
# 19   JJ                                         Degree=Pos     4   amod
# 20   NN                                        Number=Sing     1    obl
# 21   DT                           Number=Sing|PronType=Dem     6    det
# 22  NNP                                        Number=Sing     8  nsubj
# 23  VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...     8    aux
# 24  VBG                                       VerbForm=Ger     0   root
# 25  JJR                                         Degree=Cmp    10   amod
# 26   NN                                        Number=Sing     8    obj
# 27   IN                                                  _    13   case
# 28   JJ                                         Degree=Pos    13   amod
# 29   NN                                        Number=Sing     8    obl
#
#     head_dep space  predicate_prediction  label_ident_prediction  \
# 17   8:advcl     _                 False                   False
# 18    4:case     _                 False                   False
# 19    4:amod     _                 False                   False
# 20  1:obl:to     _                 False                   False
# 21     6:det     _                 False                   False
# 22   8:nsubj     _                 False                   False
# 23     8:aux     _                 False                   False
# 24    0:root     _                 False                   False
# 25   10:amod     _                 False                   False
# 26     8:obj     _                 False                   False
# 27   13:case     _                 False                   False
# 28   13:amod     _                 False                   False
# 29  8:obl:in     _                 False                   False
#
#     label_prediction  predicate_gold  label_ident_gold label_gold  passive  \
# 17               NaN           False             False          _      NaN
# 18               NaN           False             False          _      NaN
# 19               NaN           False             False          _      NaN
# 20               NaN           False             False          _      NaN
# 21               NaN           False             False          _      NaN
# 22               NaN           False             False          _      NaN
# 23               NaN            True             False          _      NaN
# 24               NaN           False             False          _      NaN
# 25               NaN           False             False          _      NaN
# 26               NaN           False             False          _      NaN
# 27               NaN           False             False          _      NaN
# 28               NaN           False             False          _      NaN
# 29               NaN           False             False          _      NaN
#
#                                      full_constituent
# 17  Compare to last decade this University is gain...
# 18                                     to last decade
# 19                                               last
# 20                                        last decade
# 21                                               this
# 22                                    this University
# 23                                                 is
# 24  to last decade this University is gaining more...
# 25                                               more
# 26                                      more prestige
# 27                             in International level
# 28                                      International
# 29                                International level
# '\n'
# ** sentence :  1
# *  sentence repetition : 2
#     sentenceId  sentenceRepetition  id           form          lemma   upos  \
# 30           1                   2   1        Compare        compare   VERB
# 31           1                   2   2             to             to    ADP
# 32           1                   2   3           last           last    ADJ
# 33           1                   2   4         decade         decade   NOUN
# 34           1                   2   5           this           this    DET
# 35           1                   2   6     University     University  PROPN
# 36           1                   2   7             is             be    AUX
# 37           1                   2   8        gaining           gain   VERB
# 38           1                   2   9           more           more    ADJ
# 39           1                   2  10       prestige       prestige   NOUN
# 40           1                   2  11             in             in    ADP
# 41           1                   2  12  International  international    ADJ
# 42           1                   2  13          level          level   NOUN
#
#    xpos                                              morph  head    dep  \
# 30  VBN                           Tense=Past|VerbForm=Part     8  advcl
# 31   IN                                                  _     4   case
# 32   JJ                                         Degree=Pos     4   amod
# 33   NN                                        Number=Sing     1    obl
# 34   DT                           Number=Sing|PronType=Dem     6    det
# 35  NNP                                        Number=Sing     8  nsubj
# 36  VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...     8    aux
# 37  VBG                                       VerbForm=Ger     0   root
# 38  JJR                                         Degree=Cmp    10   amod
# 39   NN                                        Number=Sing     8    obj
# 40   IN                                                  _    13   case
# 41   JJ                                         Degree=Pos    13   amod
# 42   NN                                        Number=Sing     8    obl
#
#     head_dep space  predicate_prediction  label_ident_prediction  \
# 30   8:advcl     _                 False                   False
# 31    4:case     _                 False                   False
# 32    4:amod     _                 False                   False
# 33  1:obl:to     _                 False                   False
# 34     6:det     _                 False                   False
# 35   8:nsubj     _                 False                    True
# 36     8:aux     _                 False                   False
# 37    0:root     _                 False                   False
# 38   10:amod     _                 False                   False
# 39     8:obj     _                 False                    True
# 40   13:case     _                 False                   False
# 41   13:amod     _                 False                   False
# 42  8:obl:in     _                 False                    True
#
#     label_prediction  predicate_gold  label_ident_gold label_gold  passive  \
# 30               NaN           False              True   ARGM-ADV      NaN
# 31               NaN           False             False          _      NaN
# 32               NaN           False             False          _      NaN
# 33               NaN           False             False          _      NaN
# 34               NaN           False             False          _      NaN
# 35               NaN           False              True       ARG0      NaN
# 36               NaN           False             False          _      NaN
# 37               NaN            True             False          _      NaN
# 38               NaN           False             False          _      NaN
# 39               NaN           False              True       ARG1      NaN
# 40               NaN           False             False          _      NaN
# 41               NaN           False             False          _      NaN
# 42               NaN           False              True   ARGM-ADV      NaN
#
#                                      full_constituent
# 30  Compare to last decade this University is gain...
# 31                                     to last decade
# 32                                               last
# 33                                        last decade
# 34                                               this
# 35                                    this University
# 36                                                 is
# 37  to last decade this University is gaining more...
# 38                                               more
# 39                                      more prestige
# 40                             in International level
# 41                                      International
# 42                                International level
# '\n'

# %%
predicate_id = int(df_sentence_repetition[df_sentence_repetition[predicate_column] == True].id)
predicate_id
# Out:
# 8

# %%
df_sentence_repetition[df_sentence_repetition['head'] == predicate_id].label_ident_prediction = True
df_sentence_repetition[df_sentence_repetition.dep == 'punct'].index[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-973ce580a950> in <module>
#       1 df_sentence_repetition[df_sentence_repetition['head'] == predicate_id].label_ident_prediction = True
# ----> 2 df_sentence_repetition[df_sentence_repetition.dep == 'punct'].index[0]
#
# ~/anaconda3/envs/swt/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
predicate_identification = np.where(df_sentence_repetition[predicate_column] == True)[0]
if len(predicate_identification) == 1:
    index_of_pred = np.where(df_sentence_repetition[predicate_column] == True)[0][0]
index_of_pred
# Out:
# 7

# %%
predicates[0]
predicates
# Out:
# array([ True, False, False, False, False, False,  True,  True, False,
#        False, False, False, False])

# %%
pred
# Out:
# array([ True, False, False, False, False,  True,  True, False, False,
#         True, False, False,  True])

# %%
for i in range(len(pred)):
    # if this token is a predicate
    if predicates[i] == True:
        pred[i] = False
        print(i)
    #else:
        #pred[i] = 'BLA'
# Out:
# 0
# 6
# 7

# %%
pred
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#         True, False, False,  True])
